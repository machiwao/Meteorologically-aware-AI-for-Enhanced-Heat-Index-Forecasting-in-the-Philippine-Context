# %%
import folium

# Center over Luzon
m = folium.Map(location=[15.5, 121.0], zoom_start=6)

# List of locations
locations = [
    {"latitude": 14.5047, "longitude": 121.004751, "name": "NAIA", "elevation_m": 21, "radius_m": 25000},
    {"latitude": 14.58841, "longitude": 120.967866, "name": "Port Area", "elevation_m": 15, "radius_m": 25000},
    {"latitude": 14.645072, "longitude": 121.044282, "name": "Science Garden", "elevation_m": 42, "radius_m": 25000},
    {"latitude": 16.403992, "longitude": 120.60147, "name": "Baguio", "elevation_m": 1510.08, "radius_m": 25000},
    {"latitude": 18.183016, "longitude": 120.534723, "name": "Laoag", "elevation_m": 5, "radius_m": 25000},
    {"latitude": 17.89019, "longitude": 120.459762, "name": "Sinait", "elevation_m": 58.129, "radius_m": 25000},
    {"latitude": 16.086784, "longitude": 120.352045, "name": "Dagupan", "elevation_m": 2, "radius_m": 25000},
    {"latitude": 17.647678, "longitude": 121.758469, "name": "Tuguegarao", "elevation_m": 62, "radius_m": 25000},
    {"latitude": 18.360059, "longitude": 121.630454, "name": "Aparri", "elevation_m": 3, "radius_m": 25000},
    {"latitude": 20.427284, "longitude": 121.970536, "name": "Basco Radar", "elevation_m": 167, "radius_m": 25000},
    {"latitude": 15.748809, "longitude": 121.632028, "name": "Baler Radar", "elevation_m": 173, "radius_m": 25000},
    {"latitude": 15.470387, "longitude": 120.951143, "name": "Cabanatuan", "elevation_m": 32, "radius_m": 25000},
    {"latitude": 15.73586, "longitude": 120.9368, "name": "CLSU", "elevation_m": 7.6, "radius_m": 25000},
    {"latitude": 15.1717, "longitude": 120.5616667, "name": "Clark", "elevation_m": 151.564, "radius_m": 25000},
    {"latitude": 15.328408, "longitude": 119.965661, "name": "Iba", "elevation_m": 5.538, "radius_m": 25000},
    {"latitude": 14.09008056, "longitude": 121.0552444, "name": "Ambulong", "elevation_m": 11, "radius_m": 25000},
    {"latitude": 14.494953, "longitude": 120.906838, "name": "Sangley Point", "elevation_m": 3, "radius_m": 25000},
    {"latitude": 14.581167, "longitude": 121.36927, "name": "Tanay", "elevation_m": 650, "radius_m": 25000},
    {"latitude": 14.74663611, "longitude": 121.6490333, "name": "Infanta", "elevation_m": 7, "radius_m": 25000},
    {"latitude": 14.018428, "longitude": 121.596575, "name": "Tayabas", "elevation_m": 158, "radius_m": 25000},
    {"latitude": 13.409775, "longitude": 121.1896667, "name": "Calapan", "elevation_m": 41, "radius_m": 25000},
    {"latitude": 12.359602, "longitude": 121.04788, "name": "San Jose", "elevation_m": 3.314, "radius_m": 25000},
    {"latitude": 9.740134, "longitude": 118.758613, "name": "Puerto Princesa", "elevation_m": 16.76, "radius_m": 25000},
    {"latitude": 14.128689, "longitude": 122.982559, "name": "Daet", "elevation_m": 3.77, "radius_m": 25000},
    {"latitude": 13.150937, "longitude": 123.728605, "name": "Legazpi", "elevation_m": 15.487, "radius_m": 25000},
    {"latitude": 13.576558, "longitude": 124.209834, "name": "Virac Synop", "elevation_m": 31.574, "radius_m": 25000}
]

# Add markers and circles
for loc in locations:
    popup_text = f"""
    <b>{loc['name']}</b><br>
    Latitude: {loc['latitude']}<br>
    Longitude: {loc['longitude']}<br>
    Elevation: {loc['elevation_m']} m<br>
    Radius: {loc['radius_m']/1000} km
    """

    folium.Marker(
        location=[loc["latitude"], loc["longitude"]],
        popup=folium.Popup(popup_text, max_width=250),
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(m)

    folium.Circle(
        radius=loc["radius_m"],
        location=[loc["latitude"], loc["longitude"]],
        color="blue",
        fill=True,
        fill_opacity=0.3
    ).add_to(m)

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce81ceca3e0811afcec2227d178346e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce81ceca3e0811afcec2227d178346e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce81ceca3e0811afcec2227d178346e6 = L.map(
#                 &quot;map_ce81ceca3e0811afcec2227d178346e6&quot;,
#                 {
#                     center: [15.5, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70a7e1c66fdf2838542757c5e1e8ddab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70a7e1c66fdf2838542757c5e1e8ddab.addTo(map_ce81ceca3e0811afcec2227d178346e6);
#
#
#             var marker_e64021c33aef3fdd35889f4c3decf23a = L.marker(
#                 [14.5047, 121.004751],
#                 {
# }
#             ).addTo(map_ce81ceca3e0811afcec2227d178346e6);
#
#
#             var icon_24aeb0ef0597c52e75a4fd5764fe5d77 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e79fc9200cdebafd65aa78e59a1983e5 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_ad92eb2503d58444fde41297dac36838 = $(`&lt;div id=&quot;html_ad92eb2503d58444fde41297dac36838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;NAIA&lt;/b&gt;&lt;br&gt;     Latitude: 14.5047&lt;br&gt;     Longitude: 121.004751&lt;br&gt;     Elevation: 21 m&lt;br&gt;     Radius: 25.0 km     &lt;/div&gt;`)[0];
#                 popup_e79fc9200cdebafd65aa78e59a1983e5.setContent(html_ad92eb2503d58444fde41297dac36838);
#
#
#
#         marker_e64021c33aef3fdd35889f4c3decf23a.bindPopup(popup_e79fc9200cdebafd65aa78e59a1983e5)
#         ;
#
#
#
#
#                 marker_e64021c33aef3fdd35889f4c3decf23a.setIcon(icon_24aeb0ef0597c52e75a4fd5764fe5d77);
#
#
#             var circle_495b910aff76263a0b998b4796e5c78c = L.circle(
#                 [14.5047, 121.004751],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ce81ceca3e0811afcec2227d178346e6);
#
#
#             var marker_83870d092dd827aebd5ac0353063a0c7 = L.marker(
#                 [14.58841, 120.967866],
#                 {
# }
#             ).addTo(map_ce81ceca3e0811afcec2227d178346e6);
#
#
#             var icon_f15fe55c0df67bb6b3871e9e77f31197 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3f3f8025a1dd34a47694b16736b5f95d = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_5fcc56fe29c4d071ed52d45d85357b30 = $(`&lt;div id=&quot;html_5fcc56fe29c4d071ed52d45d85357b30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Port Area&lt;/b&gt;&lt;br&gt;     Latitude: 14.58841&lt;br&gt;     Longitude: 120.967866&lt;br&gt;     Elevation: 15 m&lt;br&gt;     Radius: 25.0 km     &lt;/div&gt;`)[0];
#                 popup_3f3f8025a1dd34a47694b16736b5f95d.setContent(html_5fcc56fe29c4d071ed52d45d85357b30);
#
#
#
#         marker_83870d092dd827aebd5ac0353063a0c7.bindPopup(popup_3f3f8025a1dd34a47694b16736b5f95d)
#         ;
#
#
#
#
#                 marker_83870d092dd827aebd5ac0353063a0c7.setIcon(icon_f15fe55c0df67bb6b3871e9e77f31197);
#
#
#             var circle_b12998e9ce351f64cfef72aff27a6685 = L.circle(
#                 [14.58841, 120.967866],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;
